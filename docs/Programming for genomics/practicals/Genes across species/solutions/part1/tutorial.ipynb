# %%
import gff

# %%
import pandas

# %%
pandas.read_table( "../../data/PlasmoDB-54_Pfalciparum3D7.gff", comment = '#' )
# Out:
#        Pf3D7_13_v3  VEuPathDB  protein_coding_gene  624510  626292  .  + ..1  \
# 0      Pf3D7_13_v3  VEuPathDB                 mRNA  624510  626292  .  +   .
# 1      Pf3D7_13_v3  VEuPathDB                 exon  624510  626292  .  +   .
# 2      Pf3D7_13_v3  VEuPathDB                  CDS  624785  626011  .  +   0
# 3      Pf3D7_13_v3  VEuPathDB       five_prime_UTR  624510  624784  .  +   .
# 4      Pf3D7_13_v3  VEuPathDB      three_prime_UTR  626012  626292  .  +   .
# ...            ...        ...                  ...     ...     ... .. ..  ..
# 50064  Pf3D7_13_v3  VEuPathDB       five_prime_UTR  957496  958095  .  -   .
# 50065  Pf3D7_02_v3  VEuPathDB  protein_coding_gene  701245  702894  .  +   .
# 50066  Pf3D7_02_v3  VEuPathDB                 mRNA  701245  702894  .  +   .
# 50067  Pf3D7_02_v3  VEuPathDB                 exon  701245  702894  .  +   .
# 50068  Pf3D7_02_v3  VEuPathDB                  CDS  701245  702894  .  +   0
#
# ...
